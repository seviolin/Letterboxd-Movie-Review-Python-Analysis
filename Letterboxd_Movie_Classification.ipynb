# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Letterbox Movie Classification.csv')
print(df)
# Out:
#          no           Film_title           Director  Average_rating  \
# 0         0              The Fan    Eckhart Schmidt        3.570000
# 1         1   Mad Max: Fury Road      George Miller        4.180000
# 2         2             Suspiria      Dario Argento        3.930000
# 3         3  Lost in Translation      Sofia Coppola        3.790000
# 4         4                Akira    Katsuhiro Otomo        4.280000
# ...     ...                  ...                ...             ...
# 9995   9997      Evil Never Dies           Uli Edel        3.268535
# 9996   9998   The Master Butcher           Uli Edel        3.268535
# 9997   9999      Unterm Birnbaum           Uli Edel        3.268535
# 9998  10000             Simulant       April Mullen        2.260000
# 9999  10001             Roujin Z  Hiroyuki Kitakubo        3.590000
#
#                                           Genres  Runtime Original_language  \
# 0                            ['Horror', 'Drama']     92.0            German
# 1     ['Adventure', 'Science Fiction', 'Action']    121.0           English
# 2                                     ['Horror']     99.0           English
# 3                 ['Drama', 'Comedy', 'Romance']    102.0           English
# 4     ['Animation', 'Action', 'Science Fiction']    124.0          Japanese
# ...                                          ...      ...               ...
# 9995          ['TV Movie', 'Thriller', 'Horror']    205.0           English
# 9996                       ['TV Movie', 'Drama']    176.0            German
# 9997                       ['Drama', 'TV Movie']     89.0            German
# 9998             ['Thriller', 'Science Fiction']     95.0           English
# 9999   ['Animation', 'Science Fiction', 'Drama']     80.0          Japanese
#
#                                             Description  \
# 0     The hero-worship that Simone has for a pop sin...
# 1     An apocalyptic story set in the furthest reach...
# 2     An American newcomer to a prestigious German b...
# 3     Two lost souls visiting Tokyo -- the young, ne...
# 4     A secret military project endangers Neo-Tokyo ...
# ...                                                 ...
# 9995  After his wife is brutally murdered, a policem...
# 9996  After his return from World War I, there is no...
# 9997  After the death of their child, the Hradschek ...
# 9998  Faye attempts to replace her newly deceased hu...
# 9999  Mr. Takazawa, an elderly invalid who is cared ...
#
#                                                 Studios  Watches  \
# 0                           ['Barbara Moorse Workshop']    12841
# 1     ['Warner Bros. Pictures', 'Village Roadshow Pi...  2488721
# 2                                   ['Seda Spettacoli']   618171
# 3              ['American Zoetrope', 'Elemental Films']  1596190
# 4     ['MBS', 'Sumitomo Corporation', 'TOHO', 'Studi...   873068
# ...                                                 ...      ...
# 9995  ['Wolper Organization', 'Warner Bros. Televisi...      108
# 9996  ['Pakt Media', 'ARD', 'Moovie', 'ARD Degeto', ...      227
# 9997                           ['mecom fiction', 'ARD']       82
# 9998  ['Wango Films', 'Myriad Pictures', 'Particular...     4239
# 9999  ['Tokyo Theatres Company', 'Sony Music Enterta...     9351
#
#       List_appearances   Likes   Fans  1_star  3_stars  5_stars  Total_ratings
# 0                11032    3763     79     129     1660      714           9042
# 1               331681  927538  38000   12530   158356   511140        1682389
# 2               220094  219548  13000    2814    53427    88628         443757
# 3               254180  493248  38000   15167   155110   193717        1076949
# 4               175586  341567  21000    1822    40850   196532         600721
# ...                ...     ...    ...     ...      ...      ...            ...
# 9995               163      10      0       7       10        5             56
# 9996                84      45      0       2       43        9            170
# 9997                43       4      0       4        9        0             61
# 9998              1135     345      0     369      491       41           3274
# 9999              4041    2284      9      24     1405      316           6009
#
# [10000 rows x 17 columns]

# %% [markdown]
# ## EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   no                 10000 non-null  int64
#  1   Film_title         10000 non-null  object
#  2   Director           10000 non-null  object
#  3   Average_rating     10000 non-null  float64
#  4   Genres             10000 non-null  object
#  5   Runtime            10000 non-null  float64
#  6   Original_language  10000 non-null  object
#  7   Description        10000 non-null  object
#  8   Studios            10000 non-null  object
#  9   Watches            10000 non-null  int64
#  10  List_appearances   10000 non-null  int64
#  11  Likes              10000 non-null  int64
#  12  Fans               10000 non-null  int64
#  13  1_star             10000 non-null  int64
#  14  3_stars            10000 non-null  int64
#  15  5_stars            10000 non-null  int64
#  16  Total_ratings      10000 non-null  int64
# dtypes: float64(2), int64(9), object(6)
# memory usage: 1.3+ MB

# %%
df.isna().sum()
# Out:
# no                   0
# Film_title           0
# Director             0
# Average_rating       0
# Genres               0
# Runtime              0
# Original_language    0
# Description          0
# Studios              0
# Watches              0
# List_appearances     0
# Likes                0
# Fans                 0
# 1_star               0
# 3_stars              0
# 5_stars              0
# Total_ratings        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(15)
# Out:
#     no                   Film_title           Director  Average_rating  \
# 0    0                      The Fan    Eckhart Schmidt            3.57
# 1    1           Mad Max: Fury Road      George Miller            4.18
# 2    2                     Suspiria      Dario Argento            3.93
# 3    3          Lost in Translation      Sofia Coppola            3.79
# 4    4                        Akira    Katsuhiro Otomo            4.28
# 5    5               Things to Come    Mia Hansen-Løve            3.77
# 6    6  Big Trouble in Little China     John Carpenter            3.72
# 7    7                    Star Wars       George Lucas            4.17
# 8    8                The Third Man         Carol Reed            4.25
# 9    9                 The Big Sick  Michael Showalter            3.76
# 10  10            Jodorowsky's Dune       Frank Pavich            3.96
# 11  11                      Get Out       Jordan Peele            4.15
# 12  12           Lawrence of Arabia         David Lean            4.38
# 13  13                    Free Fire       Ben Wheatley            3.16
# 14  14                  Sing Street        John Carney            4.04
#
#                                           Genres  Runtime Original_language  \
# 0                            ['Horror', 'Drama']     92.0            German
# 1     ['Adventure', 'Science Fiction', 'Action']    121.0           English
# 2                                     ['Horror']     99.0           English
# 3                 ['Drama', 'Comedy', 'Romance']    102.0           English
# 4     ['Animation', 'Action', 'Science Fiction']    124.0          Japanese
# 5                                      ['Drama']    102.0            French
# 6   ['Comedy', 'Adventure', 'Fantasy', 'Action']    100.0           English
# 7     ['Adventure', 'Action', 'Science Fiction']    121.0           English
# 8                        ['Mystery', 'Thriller']    105.0           English
# 9                 ['Drama', 'Comedy', 'Romance']    120.0           English
# 10                               ['Documentary']     90.0           English
# 11             ['Horror', 'Mystery', 'Thriller']    104.0           English
# 12               ['Adventure', 'War', 'History']    228.0           English
# 13                ['Action', 'Crime', 'Mystery']     90.0           English
# 14       ['Romance', 'Drama', 'Music', 'Comedy']    105.0           English
#
#                                           Description  \
# 0   The hero-worship that Simone has for a pop sin...
# 1   An apocalyptic story set in the furthest reach...
# 2   An American newcomer to a prestigious German b...
# 3   Two lost souls visiting Tokyo -- the young, ne...
# 4   A secret military project endangers Neo-Tokyo ...
# 5   Nathalie teaches philosophy at a high school i...
# 6   Truck driver Jack Burton gets embroiled in a s...
# 7   Princess Leia is captured and held hostage by ...
# 8   In postwar Vienna, Austria, Holly Martins, a w...
# 9   Pakistan-born comedian Kumail Nanjiani and gra...
# 10  Shot in France, England, Switzerland and the U...
# 11  Chris and his girlfriend Rose go upstate to vi...
# 12  The story of British officer T.E. Lawrence's m...
# 13  Set in Boston in 1978, a meeting in a deserted...
# 14  A boy growing up in Dublin during the 1980s es...
#
#                                               Studios  Watches  \
# 0                         ['Barbara Moorse Workshop']    12841
# 1   ['Warner Bros. Pictures', 'Village Roadshow Pi...  2488721
# 2                                 ['Seda Spettacoli']   618171
# 3            ['American Zoetrope', 'Elemental Films']  1596190
# 4   ['MBS', 'Sumitomo Corporation', 'TOHO', 'Studi...   873068
# 5   ['ARTE France Cinéma', 'Detailfilm', 'CG Ciném...    34777
# 6   ['TAFT Entertainment Pictures', '20th Century ...   283873
# 7              ['Lucasfilm Ltd.', '20th Century Fox']  3014320
# 8                        ['London Films Productions']   228162
# 9   ['FilmNation Entertainment', 'Apatow Productio...   382201
# 10  ['Snowfort Pictures', 'Caméra One', 'Endless P...    85388
# 11  ['Monkeypaw Productions', 'Blumhouse Productio...  4376009
# 12                               ['Horizon Pictures']   369742
# 13  ['Rook Films', 'Protagonist Pictures', 'Film4 ...   109849
# 14  ['Likely Story', 'FilmWave', 'Distressed Films...   390910
#
#     List_appearances    Likes   Fans  1_star  3_stars  5_stars  Total_ratings
# 0              11032     3763     79     129     1660      714           9042
# 1             331681   927538  38000   12530   158356   511140        1682389
# 2             220094   219548  13000    2814    53427    88628         443757
# 3             254180   493248  38000   15167   155110   193717        1076949
# 4             175586   341567  21000    1822    40850   196532         600721
# 5              14370     8585    192      90     4274     1677          24383
# 6              65558    85788   3800    1250    30582    24938         183927
# 7             391415  1057816  30000    6041   161969   550396        1780203
# 8             101285    70932   3400     351    11549    39520         152601
# 9              58859    93489    504    1410    36987    18997         238309
# 10             16745    25616    188     209     6825     6696          56507
# 11            454087  1867622  33000   10251   272655   943393        3121586
# 12            151348   116793  10000    1080    16158    86313         242207
# 13             29433    21524     83    1528    22924     1853          81191
# 14             90763   145995  10000     846    27808    55425         273809

# %%
df.describe()
# Out:
#                  no  Average_rating       Runtime       Watches  \
# count  10000.000000    10000.000000  10000.000000  1.000000e+04
# mean    4999.778800        3.268535    103.169352  1.703148e+05
# std     2887.257342        0.525744     38.070735  4.585329e+05
# min        0.000000        1.080000      2.000000  2.000000e+00
# 25%     2499.750000        2.950000     89.000000  2.979750e+03
# 50%     4999.500000        3.268535     99.000000  1.842500e+04
# 75%     7500.250000        3.620000    113.000000  1.083580e+05
# max    10001.000000        4.710000    907.000000  5.195503e+06
#
#        List_appearances         Likes           Fans         1_star  \
# count      10000.000000  1.000000e+04   10000.000000   10000.000000
# mean       26868.798600  4.373479e+04    1652.549700    1837.319600
# std        56751.328696  1.515314e+05    9368.258118    5617.492419
# min           33.000000  0.000000e+00       0.000000       0.000000
# 25%         1674.000000  4.570000e+02       2.000000      35.000000
# 50%         6503.000000  3.394000e+03      24.000000     181.000000
# 75%        23908.250000  2.011225e+04     283.000000    1083.250000
# max       803670.000000  2.730813e+06  326000.000000  176637.000000
#
#              3_stars       5_stars  Total_ratings
# count   10000.000000  1.000000e+04   1.000000e+04
# mean    17887.078300  1.817158e+04   1.063923e+05
# std     43713.123082  8.323460e+04   2.947343e+05
# min         0.000000  0.000000e+00   0.000000e+00
# 25%       422.750000  6.000000e+01   1.895000e+03
# 50%      2422.500000  5.720000e+02   1.182300e+04
# 75%     12727.000000  4.583250e+03   6.749875e+04
# max    629879.000000  2.010363e+06   4.091037e+06

# %%
1. Top 5 directors with the most movies watched

# %%
top_5_directors = df.groupby('Director')['Watches'].sum().sort_values(ascending=False).head(5)
print(top_5_directors)
# Out:
# Director
# Christopher Nolan    28325967
# Steven Spielberg     26694256
# Quentin Tarantino    23626115
# David Fincher        20516412
# Martin Scorsese      16542747
# Name: Watches, dtype: int64

# %%
top_directors_df = df[df['Director'].isin(top_5_directors.index)]

result = top_directors_df.groupby('Director').agg({
    'Watches': 'sum',
    'Film_title': lambda x: list(x)
}).sort_values('Watches', ascending=False)
print(result)
# Out:
#                     Watches                                         Film_title
# Director
# Christopher Nolan  28325967  [The Dark Knight, Memento, Dunkirk, The Dark K...
# Steven Spielberg   26694256  [Indiana Jones and the Temple of Doom, Empire ...
# Quentin Tarantino  23626115  [Django Unchained, Pulp Fiction, Kill Bill: Vo...
# David Fincher      20516412  [Gone Girl, Fight Club, The Girl with the Drag...
# Martin Scorsese    16542747  [The King of Comedy, Mean Streets, Taxi Driver...

# %% [markdown]
# 2. What is the most appeared in list appearance?

# %%
top_movies_by_appearance = df.sort_values('List_appearances', ascending=False)[['Film_title', 'List_appearances']].head()
print(top_movies_by_appearance)
# Out:
#                              Film_title  List_appearances
# 136                     The Dark Knight            803670
# 7553                           Parasite            653081
# 243                        Interstellar            623593
# 88                           La La Land            620072
# 9125  Everything Everywhere All at Once            591205

# %% [markdown]
# 3. Language distribution

# %%
plt.figure(figsize=(10, 6))
language_counts = df['Original_language'].value_counts()
sns.countplot(data=df, x='Original_language', order=language_counts.index, palette='Set3')
plt.title('Language distribution of movies')
plt.xlabel('Original Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Top 5 movies with 5-star ratings

# %%
top_5_5_stars = (
    df.groupby('5_stars')
    .agg({
        'Film_title': lambda x: list(x),
        'Director': 'sum',
    })
)
top_5_5_stars = top_5_5_stars.sort_values('Director', ascending=False).head(5)
print(top_5_5_stars)
# Out:
#                                                 Film_title  \
# 5_stars
# 2169                    [The Specials, House of Tolerance]
# 2643              [Pauline at the Beach, Think Like a Man]
# 3344     [Claire's Knee, Intolerance: Love's Struggle T...
# 10077                                    [A Summer's Tale]
# 900                                           [The Insult]
#
#                                                Director
# 5_stars
# 2169     Éric Toledano, Olivier NakacheBertrand Bonello
# 2643                               Éric RohmerTim Story
# 3344                           Éric RohmerD.W. Griffith
# 10077                                       Éric Rohmer
# 900                                        Ziad Doueiri

# %% [markdown]
# 5. Top 5 movies with 3-star ratings

# %%
top_5_3_stars = (
    df.groupby('3_stars')
    .agg({
        'Film_title': lambda x: list(x),
        'Director': 'sum',
    })
)
top_5_3_stars = top_5_3_stars.sort_values('Director', ascending=False).head(5)
print(top_5_3_stars)
# Out:
#                                                 Film_title  \
# 3_stars
# 395      [When Eight Bells Toll, Higher Ground, John an...
# 315      [Triple Agent, Last Train Home, The Blue Bird,...
# 4396                                [Pauline at the Beach]
# 4600                                       [Claire's Knee]
# 5316                                     [A Summer's Tale]
#
#                                                   Director
# 3_stars
# 395      Étienne PérierVera FarmigaPeter YatesJamil Deh...
# 315            Éric RohmerLixin FanWalter LangAbel Ferrara
# 4396                                           Éric Rohmer
# 4600                                           Éric Rohmer
# 5316                                           Éric Rohmer

# %% [markdown]
# 6. Top 5 movies with 1-star ratings

# %%
top_5_1_star = (
    df.groupby('1_star')
    .agg({
        'Film_title': lambda x: list(x),
        'Director': 'sum',
    })
)
top_5_1_star = top_5_1_star.sort_values('Director', ascending=False).head(5)
print(top_5_1_star)
# Out:
#                                                Film_title  \
# 1_star
# 460     [Hero, Lady Vengeance, Money Train, Space Swee...
# 7675                                     [The Great Wall]
# 470                                            [Prospect]
# 4702                                               [1922]
# 6922                          [Watchmen, Howard the Duck]
#
#                                                 Director
# 1_star
# 460     Zhang YimouPark Chan-wookJoseph RubenJo Sung-hee
# 7675                                         Zhang Yimou
# 470                      Zeek Earl, Christopher Caldwell
# 4702                                        Zak Hilditch
# 6922                            Zack SnyderWillard Huyck

# %% [markdown]
# 7. Distribution of average rating

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Average_rating'], bins=20, kde=True, color='teal')
plt.title('Distribution of Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# 8. What is the shortest and longest movie?

# %%
shortest_movie = df[df['Runtime'] == df['Runtime'].min()]
longest_movie = df[df['Runtime'] == df['Runtime'].max()]

print("Shortest Movie:")
print(shortest_movie[['Film_title', 'Runtime', 'Director']])

print("\nLongest Movie:")
print(longest_movie[['Film_title', 'Runtime', 'Director']])
# Out:
# Shortest Movie:
#                 Film_title  Runtime        Director
# 6016  The Sky-Colored Seed      2.0  Hayao Miyazaki
#
# Longest Movie:
#                  Film_title  Runtime                  Director
# 8826  Berlin Alexanderplatz    907.0  Rainer Werner Fassbinder
